# %%
import os
import pandas as pd
import moviepy

# %%
video_root_dir = "./data/videos/pond-water-rotifers/"  #individual-rotifer/"
image_root_dir = "./data/images/"

video_files = sorted([f for f in os.listdir(video_root_dir) if f.endswith(".MP4")])
video_filepaths = [os.path.join(video_root_dir, f) for f in video_files]

print(video_files[:10], "\n", video_filepaths[:10])
# Out:
# ['2020_0107_010256_004.MP4', '2020_0109_035310_014.MP4', '2020_0109_060802_030.MP4', '2024_0104_121454_057.MP4', '2024_0109_113533_051.MP4', '2024_0116_120310_060.MP4', '2024_0116_121239_064.MP4', '2024_0116_150020_071.MP4', '2024_0116_171238_072.MP4', '2024_0116_181251_078.MP4']
#  ['./data/videos/pond-water-rotifers/2020_0107_010256_004.MP4', './data/videos/pond-water-rotifers/2020_0109_035310_014.MP4', './data/videos/pond-water-rotifers/2020_0109_060802_030.MP4', './data/videos/pond-water-rotifers/2024_0104_121454_057.MP4', './data/videos/pond-water-rotifers/2024_0109_113533_051.MP4', './data/videos/pond-water-rotifers/2024_0116_120310_060.MP4', './data/videos/pond-water-rotifers/2024_0116_121239_064.MP4', './data/videos/pond-water-rotifers/2024_0116_150020_071.MP4', './data/videos/pond-water-rotifers/2024_0116_171238_072.MP4', './data/videos/pond-water-rotifers/2024_0116_181251_078.MP4']

# %%
from moviepy.editor import VideoFileClip


def get_video_info(file_path):
    clip = VideoFileClip(file_path)
    duration = clip.duration
    resolution = clip.size
    fps = clip.fps
    clip.close()  # Close the clip to release resources
    
    creation_time = os.path.getctime(file_path)

    return duration, resolution, fps, creation_time

# %%
video_duration = list()
video_resolution = list()
video_creation = list()
video_fps = list()

for fp in video_filepaths:
    vid_duration, vid_resolution, vid_fps, vid_creation = get_video_info(fp)
    video_duration.append(vid_duration)
    video_resolution.append(vid_resolution)
    video_creation.append(vid_creation)
    video_fps.append(vid_fps)

# %%
video_duration
# Out:
# [49.93,
#  128.23,
#  64.17,
#  100.8,
#  134.13,
#  77.12,
#  217.8,
#  205.52,
#  87.65,
#  69.08,
#  125.37,
#  108.93,
#  25.87,
#  55.08,
#  81.63,
#  28.67,
#  131.96,
#  280.88,
#  5.04,
#  45.04,
#  67.96,
#  120.63,
#  29.88,
#  63.15,
#  5.19,
#  194.63,
#  95.38,
#  140.04]

# %%
df = pd.DataFrame(video_filepaths, columns=["file_path"])
df["file_name"] = video_files
df["creation"] = video_creation
df["duration"] = video_duration
df["resolution"] = video_resolution
df["fps"] = video_fps
df["desc"] = None
df#.tail(20)
# Out:
#                                             file_path  \
# 0   ./data/videos/pond-water-rotifers/2020_0107_01...
# 1   ./data/videos/pond-water-rotifers/2020_0109_03...
# 2   ./data/videos/pond-water-rotifers/2020_0109_06...
# 3   ./data/videos/pond-water-rotifers/2024_0104_12...
# 4   ./data/videos/pond-water-rotifers/2024_0109_11...
# 5   ./data/videos/pond-water-rotifers/2024_0116_12...
# 6   ./data/videos/pond-water-rotifers/2024_0116_12...
# 7   ./data/videos/pond-water-rotifers/2024_0116_15...
# 8   ./data/videos/pond-water-rotifers/2024_0116_17...
# 9   ./data/videos/pond-water-rotifers/2024_0116_18...
# 10  ./data/videos/pond-water-rotifers/2024_0116_18...
# 11  ./data/videos/pond-water-rotifers/2024_0116_18...
# 12  ./data/videos/pond-water-rotifers/2024_0116_18...
# 13  ./data/videos/pond-water-rotifers/2024_0116_18...
# 14  ./data/videos/pond-water-rotifers/2024_0116_18...
# 15  ./data/videos/pond-water-rotifers/2024_0118_19...
# 16  ./data/videos/pond-water-rotifers/2024_0119_12...
# 17  ./data/videos/pond-water-rotifers/2024_0119_12...
# 18  ./data/videos/pond-water-rotifers/2024_0119_12...
# 19  ./data/videos/pond-water-rotifers/2024_0119_13...
# 20  ./data/videos/pond-water-rotifers/2024_0119_15...
# 21  ./data/videos/pond-water-rotifers/2024_0126_16...
# 22  ./data/videos/pond-water-rotifers/2024_0126_16...
# 23  ./data/videos/pond-water-rotifers/2024_0126_16...
# 24  ./data/videos/pond-water-rotifers/2024_0126_19...
# 25  ./data/videos/pond-water-rotifers/2024_0128_18...
# 26  ./data/videos/pond-water-rotifers/2024_0130_18...
# 27  ./data/videos/pond-water-rotifers/2024_0130_20...
#
#                    file_name      creation  duration    resolution    fps  \
# 0   2020_0107_010256_004.MP4  1.706962e+09     49.93  [1920, 1080]   30.0
# 1   2020_0109_035310_014.MP4  1.706962e+09    128.23  [1920, 1080]   30.0
# 2   2020_0109_060802_030.MP4  1.706962e+09     64.17  [1920, 1080]   30.0
# 3   2024_0104_121454_057.MP4  1.706962e+09    100.80  [1920, 1080]   30.0
# 4   2024_0109_113533_051.MP4  1.706962e+09    134.13  [2880, 2160]   24.0
# 5   2024_0116_120310_060.MP4  1.706962e+09     77.12  [1920, 1080]   60.0
# 6   2024_0116_121239_064.MP4  1.706962e+09    217.80  [1920, 1080]   60.0
# 7   2024_0116_150020_071.MP4  1.706962e+09    205.52  [1920, 1080]   60.0
# 8   2024_0116_171238_072.MP4  1.706962e+09     87.65  [1920, 1080]   60.0
# 9   2024_0116_181251_078.MP4  1.706962e+09     69.08  [1920, 1080]   60.0
# 10  2024_0116_181435_079.MP4  1.706962e+09    125.37  [1920, 1080]   60.0
# 11  2024_0116_181704_080.MP4  1.706962e+09    108.93  [1920, 1080]   60.0
# 12  2024_0116_181908_081.MP4  1.706962e+09     25.87  [1920, 1080]   60.0
# 13  2024_0116_181949_082.MP4  1.706962e+09     55.08  [1920, 1080]   60.0
# 14  2024_0116_182201_083.MP4  1.706962e+09     81.63  [1920, 1080]   60.0
# 15  2024_0118_195649_072.MP4  1.706962e+09     28.67  [2880, 2160]   24.0
# 16  2024_0119_121900_084.MP4  1.706962e+09    131.96  [2880, 2160]   24.0
# 17  2024_0119_123829_089.MP4  1.706962e+09    280.88  [2880, 2160]   24.0
# 18  2024_0119_124327_090.MP4  1.706962e+09      5.04  [2880, 2160]   24.0
# 19  2024_0119_131319_096.MP4  1.706962e+09     45.04  [2880, 2160]   24.0
# 20  2024_0119_151021_101.MP4  1.706962e+09     67.96  [2880, 2160]   24.0
# 21  2024_0126_162412_122.MP4  1.706962e+09    120.63  [2880, 2160]   24.0
# 22  2024_0126_162616_123.MP4  1.706962e+09     29.88  [2880, 2160]   24.0
# 23  2024_0126_162729_125.MP4  1.706962e+09     63.15  [1920, 1080]   60.0
# 24  2024_0126_191658_153.MP4  1.706962e+09      5.19   [1280, 720]  120.0
# 25  2024_0128_184102_011.MP4  1.706962e+09    194.63  [2880, 2160]   24.0
# 26  2024_0130_180117_035.MP4  1.706962e+09     95.38  [2880, 2160]   24.0
# 27  2024_0130_203901_037.MP4  1.706962e+09    140.04  [2880, 2160]   24.0
#
#     desc
# 0   None
# 1   None
# 2   None
# 3   None
# 4   None
# 5   None
# 6   None
# 7   None
# 8   None
# 9   None
# 10  None
# 11  None
# 12  None
# 13  None
# 14  None
# 15  None
# 16  None
# 17  None
# 18  None
# 19  None
# 20  None
# 21  None
# 22  None
# 23  None
# 24  None
# 25  None
# 26  None
# 27  None

# %%
df.to_csv("./data/csvs/metadata_pond-rotifers.csv", index=False)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
